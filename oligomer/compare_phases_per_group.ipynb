# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import sys
import pdb
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)

measure = "GDT_TS"
measure = "GDT_HA"
measure = "dockq"

# model = "first"
model = "best"

# mode = "easy"
# mode = "medium"
# mode = "hard"
mode = "all"

impute_value = -2

os.chdir('/home2/s439906/project/CASP16/oligomer/')

number2group={'TS002': 'JFK-THG-AMBER',
 'TS003': 'JFK-THG-AMBERstable',
 'TS004': 'JFK-THG-CHARMM',
 'TS005': 'JFK-THG-CHARMMstable',
 'TS006': 'RNA_Dojo',
 'TS008': 'HADDOCK',
 'TS014': 'Cool-PSP',
 'TS015': 'PEZYFoldings',
 'TS016': 'haiping',
 'TS017': 'Seder2024hard',
 'TS018': 'AttStructureScorer',
 'TS019': 'Zheng-Server',
 'TS020': 'comppharmunibas',
 'TS022': 'Yang',
 'TS023': 'FTBiot0119',
 'TS026': 'SwRI',
 'TS027': 'ModFOLDdock2R',
 'TS028': 'NKRNA-s',
 'TS029': 'zyh_mae_try1',
 'TS030': 'SNU-CHEM_aff',
 'TS031': 'MassiveFold',
 'TS032': 'Bryant',
 'TS033': 'Diff',
 'TS039': 'arosko',
 'TS040': 'DELCLAB',
    'TS044': 'N/A',
 'TS049': 'UTMB',
 'TS050': 'SHORTLE',
 'TS051': 'MULTICOM',
 'TS052': 'Yang-Server',
 'TS055': 'LCDD-team',
 'TS059': 'DeepFold',
 'TS063': 'RNApolis',
 'TS074': 'ModFOLDdock2S',
 'TS075': 'GHZ-ISM',
 'TS077': 'coogs2',
 'TS079': 'MRAFold',
 'TS080': 'pDockQ',
 'TS082': 'VnsDock',
 'TS084': 'Vendruscolo',
 'TS085': 'Bates',
 'TS088': 'orangeballs',
 'TS091': 'Huang-HUST',
 'TS092': 'Seamount',
 'TS094': 'SimRNA-server',
 'TS097': 'JFK-THG-IDPCONFGEN',
 'TS100': 'zurite_lab',
 'TS102': 'Psi-Phi',
 'TS105': 'PFSC-PFVM',
 'TS110': 'MIEnsembles-Server',
 'TS112': 'Seder2024easy',
 'TS114': 'COAST',
 'TS117': 'Vakser',
 'TS120': 'Cerebra',
 'TS121': 'Pascal_Auffinger',
 'TS122': 'MQA_server',
 'TS128': 'TheMeilerMethod',
 'TS132': 'profold2',
 'TS135': 'Lindorff-LarsenCLVDS',
 'TS136': 'Lindorff-LarsenM3PPS',
 'TS137': 'Lindorff-LarsenM3PWS',
 'TS138': 'Shengyi',
 'TS139': 'DeepFold-refine',
 'TS143': 'dMNAfold',
 'TS145': 'colabfold_baseline',
 'TS147': 'Zheng-Multimer',
 'TS148': 'Guijunlab-Complex',
 'TS156': 'SoutheRNA',
 'TS159': '406',
 'TS163': 'MultiFOLD2',
 'TS164': 'McGuffin',
 'TS165': 'dfr',
 'TS167': 'OpenComplex',
 'TS169': 'thermomaps',
 'TS171': 'ChaePred',
 'TS172': 'VoroAffinity',
 'TS174': 'colabfold_foldseek',
 'TS177': 'aicb',
 'TS183': 'GuangzhouRNA-human',
 'TS187': 'Ayush',
 'TS188': 'VifChartreuseJaune',
 'TS189': 'LCBio',
 'TS191': 'Schneidman',
 'TS196': 'HYU_MLLAB',
 'TS197': 'D3D',
 'TS198': 'colabfold',
 'TS201': 'Drugit',
 'TS202': 'test001',
 'TS204': 'Zou',
 'TS207': 'MULTICOM_ligand',
 'TS208': 'falcon2',
 'TS209': 'colabfold_human',
 'TS212': 'PIEFold_human',
 'TS217': 'zyh_mae_try1E',
 'TS218': 'HIT-LinYang',
 'TS219': 'XGroup-server',
 'TS221': 'CSSB_FAKER',
    'TS225': 'N/A',
 'TS226': 'Pfaender',
 'TS227': 'KUMC',
 'TS231': 'B-LAB',
 'TS235': 'isyslab-hust',
 'TS237': 'Convex-PL-R',
 'TS238': 'BRIQX',
 'TS241': 'elofsson',
 'TS261': 'UNRES',
 'TS262': 'CoDock',
 'TS264': 'GuijunLab-Human',
 'TS267': 'kiharalab_server',
 'TS269': 'CSSB_server',
 'TS271': 'mialab_prediction2',
 'TS272': 'GromihaLab',
 'TS273': 'MQA_base',
 'TS274': 'kozakovvajda',
 'TS275': 'Seminoles',
 'TS276': 'FrederickFolding',
 'TS281': 'T2DUCC',
 'TS284': 'Unicorn',
 'TS286': 'CSSB_experimental',
 'TS287': 'plmfold',
 'TS290': 'Pierce',
 'TS293': 'MRAH',
 'TS294': 'KiharaLab',
 'TS295': 'VoroAffinityB',
 'TS298': 'ShanghaiTech-human',
 'TS300': 'ARC',
 'TS301': 'GHZ-MAN',
 'TS304': 'AF3-server',
 'TS306': 'GeneSilicoRNA-server',
 'TS307': 'nfRNA',
 'TS308': 'MoMAteam1',
 'TS309': 'Koes',
 'TS311': 'RAGfold_Prot1',
 'TS312': 'GuijunLab-Assembly',
 'TS314': 'GuijunLab-PAthreader',
 'TS317': 'GuangzhouRNA_AI',
 'TS319': 'MULTICOM_LLM',
 'TS322': 'XGroup',
 'TS323': 'Yan',
 'TS325': '405',
 'TS331': 'MULTICOM_AI',
 'TS337': 'APOLLO',
 'TS338': 'GeneSilico',
 'TS345': 'MULTICOM_human',
 'TS349': 'cheatham-lab',
 'TS351': 'digiwiser-ensemble',
 'TS353': 'KORP-PL-W',
 'TS355': 'CMOD',
 'TS357': 'UTAustin',
 'TS358': 'PerezLab_Gators',
 'TS361': 'Cerebra_server',
 'TS363': '2Vinardo',
 'TS367': 'AIR',
 'TS369': 'Bhattacharya',
 'TS370': 'DrAshokAndFriends',
 'TS375': 'milliseconds',
 'TS376': 'OFsingleseq',
 'TS380': 'mialab_prediction',
 'TS384': 'pert-plddt',
 'TS386': 'ShanghaiTech-Ligand',
 'TS388': 'DeepFold-server',
 'TS391': 'bussilab_replex',
 'TS393': 'GuijunLab-QA',
 'TS397': 'smg_ulaval',
 'TS400': 'OmniFold',
 'TS403': 'mmagnus',
 'TS408': 'SNU-CHEM-lig',
 'TS412': 'cheatham-lab_villa',
 'TS416': 'GPLAffinity',
 'TS417': 'GuangzhouRNA-meta',
 'TS418': 'Lee-Shin',
 'TS419': 'CSSB-Human',
 'TS420': 'Zou_aff2',
 'TS423': 'ShanghaiTech-server',
 'TS425': 'MULTICOM_GATE',
 'TS432': 'DIMAIO',
 'TS435': 'RNAFOLDX',
 'TS436': 'Yoshiaki',
 'TS439': 'Dokholyan',
 'TS441': 'ModFOLDdock2',
 'TS443': 'MQA',
 'TS446': 'pDockQ2',
 'TS447': 'UDMod',
 'TS448': 'dNAfold',
 'TS450': 'OpenComplex_Server',
 'TS456': 'Yang-Multimer',
 'TS461': 'forlilab',
 'TS462': 'Zheng',
 'TS464': 'PocketTracer',
 'TS465': 'Wallner',
 'TS466': 'coogs3',
 'TS468': 'MIALAB_gong',
 'TS469': 'GruLab',
 'TS471': 'Pcons',
 'TS474': 'CCB-AlGDock',
 'TS475': 'ptq',
 'TS476': 'VifChartreuse',
 'TS481': 'Vfold',
 'TS485': 'bussilab_plain_md',
 'TS489': 'Fernandez-Recio',
 'TS494': 'ClusPro',
 'TS496': 'AF_unmasked'}

# %%
# T1_score_path = "./score_T1_o/"
# T1_score_file = f"{measure}-{model}-{mode}-raw.csv"
# T1_data = pd.read_csv(T1_score_path + T1_score_file, index_col=0)
# print(T1_data.shape)
# T0_score_path = "./score_T0_o/"
# T0_score_file = f"{measure}-{model}-{mode}-raw.csv"
# T0_data = pd.read_csv(T0_score_path + T0_score_file, index_col=0)
# print(T0_data.shape)
# T2_score_path = "./score_T2_o/"
# T2_score_file = f"{measure}-{model}-{mode}-raw.csv"
# T2_data = pd.read_csv(T2_score_path + T2_score_file, index_col=0)
# print(T2_data.shape)
# # T2_data


# # print(T0_data.shape)
# # print(T1_data.shape)
# # print(T2_data.shape)
# out_path = "./CASP16_figures_olig/"
# if not os.path.exists(out_path):
#     os.makedirs(out_path)
# T0_data = T0_data.T
# T1_data = T1_data.T
# T2_data = T2_data.T


# # T1 -T0
# T0_data.index = T0_data.index.str.extract(r'(?:T0|H0)([-\w]+)')[0]
# # there is a -D*. In order to match the "-" in the regex, we need to add "-" in the regex
# T1_data.index = T1_data.index.str.extract(r'(?:T1|H1)([-\w]+)')[0]
# # then remove the "-all" in T1_data.index
# # T1_data.index = T1_data.index.str.replace("-all", "")
# common_index = T0_data.index.intersection(T1_data.index)
# df0_aligned = T0_data.loc[common_index]
# df1_aligned = T1_data.loc[common_index]
# print(df0_aligned)
# print(df1_aligned)

# %%
measure = "GDT_TS"
measure = "GDT_HA"
measure = "dockq"

model = "first"
# model = "best"

# mode = "easy"
# mode = "medium"
# mode = "hard"
mode = "all"

impute_value = -2

T1_score_path = "./score_T1_o/"
T1_score_file = f"{measure}-{model}-{mode}-raw.csv"
T1_data = pd.read_csv(T1_score_path + T1_score_file, index_col=0)
print(T1_data.shape)
T0_score_path = "./score_T0_o/"
T0_score_file = f"{measure}-{model}-{mode}-raw.csv"
T0_data = pd.read_csv(T0_score_path + T0_score_file, index_col=0)
print(T0_data.shape)
T2_score_path = "./score_T2_o/"
T2_score_file = f"{measure}-{model}-{mode}-raw.csv"
T2_data = pd.read_csv(T2_score_path + T2_score_file, index_col=0)
print(T2_data.shape)


# print(T0_data.shape)
# print(T1_data.shape)
# print(T2_data.shape)
out_path = "./CASP16_figures_olig/"
if not os.path.exists(out_path):
    os.makedirs(out_path)
T0_data = T0_data.T
T1_data = T1_data.T
T2_data = T2_data.T

stages = ["T1", "T2"]
stages = ["T0", "T1"]
top_n = 10


# T1 -T0
T0_data.index = T0_data.index.str.extract(r'(?:T0|H0)([-\w]+)')[0]
# there is a -D*. In order to match the "-" in the regex, we need to add "-" in the regex
T1_data.index = T1_data.index.str.extract(r'(?:T1|H1)([-\w]+)')[0]
# then remove the "-all" in T1_data.index
# T1_data.index = T1_data.index.str.replace("-all", "")
common_index = T0_data.index.intersection(T1_data.index)
df0_aligned = T0_data.loc[common_index]
df1_aligned = T1_data.loc[common_index]
groups = df1_aligned.columns

top_groups =[
"TS294",
"TS051",
"TS345",
"TS052",
"TS456",
"TS022",
"TS462",
"TS147",
"TS028",
"TS110",
"TS241",
"TS221",
"TS312",
"TS148",
"TS262",
"TS274",
"TS419",
"TS304",
"TS059",
"TS264",
"TS494",
"TS015",
]

groups = [group for group in groups if group in top_groups]
diff_valid_dict = {}
diff_valid_numbers = {}
for group in groups:
    # pdb.set_trace()
    try:
        df0_aligned_target = df0_aligned[group]
    except KeyError:
        print(f"{group} not in T0")
        continue
    df1_aligned_target = df1_aligned[group]
    # take the intersection of the two dataframes where both are not null
    # 布尔索引，选择两个列都不为 NaN 的行
    valid_rows = df0_aligned_target.notna() & df1_aligned_target.notna()
    # 取出交集部分
    df0_aligned_valid = df0_aligned_target[valid_rows]
    df1_aligned_valid = df1_aligned_target[valid_rows]
    shape_0 = df0_aligned_valid.shape
    shape_1 = df1_aligned_valid.shape
    assert shape_0 == shape_1
    diff = df1_aligned_valid - df0_aligned_valid
    diff_mean = diff.mean()
    if int(shape_0[0]) > 10:
        diff_valid_dict[group] = diff_mean
        diff_valid_numbers[group] = int(shape_0[0])
# sort the dictionary by the mean of the difference
diff_valid_dict = dict(sorted(diff_valid_dict.items(), key=lambda item: item[1], reverse=True))
diff_valid_dict
group_diff_valid_dict = {}
for group in diff_valid_dict.keys():
    group_diff_valid_dict[number2group[group]] = diff_valid_dict[group]
group_diff_valid_numbers = {}
for group in diff_valid_numbers.keys():
    group_diff_valid_numbers[number2group[group]] = diff_valid_numbers[group]

# plot. add the value of diff_valid_numbers on each bar
plt.figure(figsize=(8, 5), dpi=300)
plt.bar(group_diff_valid_dict.keys(), group_diff_valid_dict.values())
for i, (key, value) in enumerate(group_diff_valid_dict.items()):
    if group_diff_valid_dict[key] > 0:
        plt.text(i, value, group_diff_valid_numbers[key], ha='center')
    else:
        # move the text to the bottom
        plt.text(i, value, group_diff_valid_numbers[key], ha='center', va='top')
    
plt.xticks(fontsize=12, rotation=90)
plt.title(f"mean {measure} improvement from T0 to T1, using {model} model", pad=20)
plt.ylabel(f"mean {measure} improvement")
max_value  = max(group_diff_valid_dict.values())
min_value = min(group_diff_valid_dict.values())
plt.ylim(min_value-0.05, max_value+0.05)
plt.tight_layout()
plt.show()
# Out:
# (87, 40)
# (67, 28)
# (87, 34)

# %%
measure = "GDT_TS"
measure = "GDT_HA"
measure = "dockq"

model = "first"
model = "best"

# mode = "easy"
# mode = "medium"
# mode = "hard"
mode = "all"

impute_value = -2

T1_score_path = "./score_T1_o/"
T1_score_file = f"{measure}-{model}-{mode}-raw.csv"
T1_data = pd.read_csv(T1_score_path + T1_score_file, index_col=0)
print(T1_data.shape)
T0_score_path = "./score_T0_o/"
T0_score_file = f"{measure}-{model}-{mode}-raw.csv"
T0_data = pd.read_csv(T0_score_path + T0_score_file, index_col=0)
print(T0_data.shape)
T2_score_path = "./score_T2_o/"
T2_score_file = f"{measure}-{model}-{mode}-raw.csv"
T2_data = pd.read_csv(T2_score_path + T2_score_file, index_col=0)
print(T2_data.shape)



# print(T0_data.shape)
# print(T1_data.shape)
# print(T2_data.shape)
out_path = "./CASP16_figures_olig/"
if not os.path.exists(out_path):
    os.makedirs(out_path)
T0_data = T0_data.T
T1_data = T1_data.T
T2_data = T2_data.T

stages = ["T0", "T1"]
stages = ["T1", "T2"]
top_n = 10


# T1 -T0
T1_data.index = T1_data.index.str.extract(r'(?:T1|H1)([-\w]+)')[0]
# there is a -D*. In order to match the "-" in the regex, we need to add "-" in the regex
T2_data.index = T2_data.index.str.extract(r'(?:T2|H2)([-\w]+)')[0]
# then remove the "-all" in T1_data.index
# T1_data.index = T1_data.index.str.replace("-all", "")
common_index = T1_data.index.intersection(T2_data.index)
df1_aligned = T1_data.loc[common_index]
df2_aligned = T2_data.loc[common_index]
groups = df2_aligned.columns
top_groups =[
"TS294",
"TS051",
"TS345",
"TS052",
"TS456",
"TS022",
"TS462",
"TS147",
"TS028",
"TS110",
"TS241",
"TS221",
"TS312",
"TS148",
"TS262",
"TS274",
"TS419",
"TS304",
"TS059",
"TS264",
"TS494",
"TS015",
]
groups = [group for group in groups if group in top_groups]

diff_valid_dict = {}
diff_valid_numbers = {}
for group in groups:
    # pdb.set_trace()
    try:
        df1_aligned_target = df1_aligned[group]
    except KeyError:
        print(f"{group} not in T1")
        continue
    df2_aligned_target = df2_aligned[group]
    # take the intersection of the two dataframes where both are not null
    # 布尔索引，选择两个列都不为 NaN 的行
    valid_rows = df1_aligned_target.notna() & df2_aligned_target.notna()
    # 取出交集部分
    df1_aligned_valid = df1_aligned_target[valid_rows]
    df2_aligned_valid = df2_aligned_target[valid_rows]
    shape_1 = df1_aligned_valid.shape
    shape_2 = df2_aligned_valid.shape
    assert shape_1 == shape_2
    diff = df2_aligned_valid - df1_aligned_valid
    diff_mean = diff.mean()
    if int(shape_1[0]) > 20:
        diff_valid_dict[group] = diff_mean
        diff_valid_numbers[group] = int(shape_1[0])



# # sort the dictionary by the mean of the difference
# diff_valid_dict = dict(sorted(diff_valid_dict.items(), key=lambda item: item[1], reverse=True))
# diff_valid_dict

# # plot. add the value of diff_valid_numbers on each bar
# plt.figure(figsize=(15, 5), dpi=300)
# plt.bar(diff_valid_dict.keys(), diff_valid_dict.values())
# for i, (key, value) in enumerate(diff_valid_dict.items()):
#     if diff_valid_dict[key] > 0:
#         plt.text(i, value, diff_valid_numbers[key], ha='center')
#     else:
#         # move the text to the bottom
#         plt.text(i, value, diff_valid_numbers[key], ha='center', va='top')
        
# plt.xticks(rotation=45, ha='right')
# plt.title(f"mean {measure} improvement from T1 to T2", fontsize=15)
# plt.ylabel(f"mean {measure} improvement")
# plt.tight_layout()
# plt.show()
# sort the dictionary by the mean of the difference
diff_valid_dict = dict(sorted(diff_valid_dict.items(), key=lambda item: item[1], reverse=True))
diff_valid_dict
group_diff_valid_dict = {}
for group in diff_valid_dict.keys():
    group_diff_valid_dict[number2group[group]] = diff_valid_dict[group]
group_diff_valid_numbers = {}
for group in diff_valid_numbers.keys():
    group_diff_valid_numbers[number2group[group]] = diff_valid_numbers[group]

# plot. add the value of diff_valid_numbers on each bar
plt.figure(figsize=(8, 5), dpi=300)
plt.bar(group_diff_valid_dict.keys(), group_diff_valid_dict.values())
for i, (key, value) in enumerate(group_diff_valid_dict.items()):
    if group_diff_valid_dict[key] > 0:
        plt.text(i, value, group_diff_valid_numbers[key], ha='center')
    else:
        # move the text to the bottom
        plt.text(i, value, group_diff_valid_numbers[key], ha='center', va='top')
     
plt.xticks(fontsize=12, rotation=90)
plt.title(f"mean {measure} improvement from T1 to T2, using {model} model", pad=20)
plt.ylabel(f"mean {measure} improvement")
max_value  = max(group_diff_valid_dict.values())
min_value = min(group_diff_valid_dict.values())
plt.ylim(min_value-0.05, max_value+0.05)
plt.tight_layout()
plt.show()
# Out:
# (87, 40)
# (67, 28)
# (87, 34)

# %%
T1_score_path = "./group_by_target_EU/"
T1_score_file = f"{measure}-{model}-{mode}-raw.csv"
T1_data = pd.read_csv(T1_score_path + T1_score_file, index_col=0)
print(T1_data.shape)
T0_score_path = "./score_T0/"
T0_score_file = f"{measure}-{model}-{mode}-raw.csv"
T0_data = pd.read_csv(T0_score_path + T0_score_file, index_col=0)
print(T0_data.shape)
T2_score_path = "./score_T2/"
T2_score_file = f"{measure}-{model}-{mode}-raw.csv"
T2_data = pd.read_csv(T2_score_path + T2_score_file, index_col=0)
print(T2_data.shape)
# T2_data


# print(T0_data.shape)
# print(T1_data.shape)
# print(T2_data.shape)
out_path = "./png/"
if not os.path.exists(out_path):
    os.makedirs(out_path)
T0_data = T0_data.T
T1_data = T1_data.T
T2_data = T2_data.T

stages = ["T0", "T1"]
stages = ["T1", "T2"]
top_n = 10


# T1 -T0
T1_data.index = T1_data.index.str.extract(r'T1([-\w]+)')[0]
# there is a -D*. In order to match the "-" in the regex, we need to add "-" in the regex
T2_data.index = T2_data.index.str.extract(r'T2([-\w]+)')[0]
# then remove the "-all" in T1_data.index
# T1_data.index = T1_data.index.str.replace("-all", "")
common_index = T1_data.index.intersection(T2_data.index)
df1_aligned = T1_data.loc[common_index]
df2_aligned = T2_data.loc[common_index]
groups = df2_aligned.columns
top_groups =["TS022",
"TS456",
"TS052",
"TS110",
"TS051",
"TS345",
"TS148",
"TS462",
"TS241",
"TS019",
"TS147",
"TS304",
"TS294",
"TS312",
"TS208",
"TS264",
"TS015",
"TS267",
"TS221",
"TS419",
"TS293",
"TS314",
"TS164",
"TS235",
"TS079",
"TS163",
"TS284",
"TS301",]
groups = [group for group in groups if group in top_groups]

diff_valid_dict = {}
diff_valid_numbers = {}
for group in groups:
    # pdb.set_trace()
    try:
        df1_aligned_target = df1_aligned[group]
    except KeyError:
        print(f"{group} not in T1")
        continue
    df2_aligned_target = df2_aligned[group]
    # take the intersection of the two dataframes where both are not null
    # 布尔索引，选择两个列都不为 NaN 的行
    valid_rows = df1_aligned_target.notna() & df2_aligned_target.notna()
    # 取出交集部分
    df1_aligned_valid = df1_aligned_target[valid_rows]
    df2_aligned_valid = df2_aligned_target[valid_rows]
    shape_1 = df1_aligned_valid.shape
    shape_2 = df2_aligned_valid.shape
    assert shape_1 == shape_2
    diff = df2_aligned_valid - df1_aligned_valid
    diff_mean = diff.mean()
    if int(shape_1[0]) > 20:
        diff_valid_dict[group] = diff_mean
        diff_valid_numbers[group] = int(shape_1[0])



# sort the dictionary by the mean of the difference
diff_valid_dict = dict(sorted(diff_valid_dict.items(), key=lambda item: item[1], reverse=True))
diff_valid_dict

# plot. add the value of diff_valid_numbers on each bar
plt.figure(figsize=(15, 5), dpi=300)
plt.bar(diff_valid_dict.keys(), diff_valid_dict.values())
for i, (key, value) in enumerate(diff_valid_dict.items()):
    if diff_valid_dict[key] > 0:
        plt.text(i, value, diff_valid_numbers[key], ha='center')
    else:
        # move the text to the bottom
        plt.text(i, value, diff_valid_numbers[key], ha='center', va='top')
        
plt.xticks(rotation=45, ha='right')
plt.title(f"mean {measure} improvement from T1 to T2", fontsize=15)
plt.ylabel(f"mean {measure} improvement")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-99f96cea5d84> in <module>
#       1 T1_score_path = "./group_by_target_EU/"
#       2 T1_score_file = f"{measure}-{model}-{mode}-raw.csv"
# ----> 3 T1_data = pd.read_csv(T1_score_path + T1_score_file, index_col=0)
#       4 print(T1_data.shape)
#       5 T0_score_path = "./score_T0/"
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ./group_by_target_EU/dockq-best-all-raw.csv does not exist: './group_by_target_EU/dockq-best-all-raw.csv'
