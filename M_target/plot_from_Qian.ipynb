# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
os.chdir('/home2/s439906/project/CASP16/M_target/')


number2group={'TS002': 'JFK-THG-AMBER',
 'TS003': 'JFK-THG-AMBERstable',
 'TS004': 'JFK-THG-CHARMM',
 'TS005': 'JFK-THG-CHARMMstable',
 'TS006': 'RNA_Dojo',
 'TS008': 'HADDOCK',
 'TS014': 'Cool-PSP',
 'TS015': 'PEZYFoldings',
 'TS016': 'haiping',
 'TS017': 'Seder2024hard',
 'TS018': 'AttStructureScorer',
 'TS019': 'Zheng-Server',
 'TS020': 'comppharmunibas',
 'TS022': 'Yang',
 'TS023': 'FTBiot0119',
 'TS026': 'SwRI',
 'TS027': 'ModFOLDdock2R',
 'TS028': 'NKRNA-s',
 'TS029': 'zyh_mae_try1',
 'TS030': 'SNU-CHEM_aff',
 'TS031': 'MassiveFold',
 'TS032': 'Bryant',
 'TS033': 'Diff',
 'TS039': 'arosko',
 'TS040': 'DELCLAB',
 'TS044': 'N/A',
 'TS049': 'UTMB',
 'TS050': 'SHORTLE',
 'TS051': 'MULTICOM',
 'TS052': 'Yang-Server',
 'TS055': 'LCDD-team',
 'TS059': 'DeepFold',
 'TS063': 'RNApolis',
 'TS074': 'ModFOLDdock2S',
 'TS075': 'GHZ-ISM',
 'TS077': 'coogs2',
 'TS079': 'MRAFold',
 'TS080': 'pDockQ',
 'TS082': 'VnsDock',
 'TS084': 'Vendruscolo',
 'TS085': 'Bates',
 'TS088': 'orangeballs',
 'TS091': 'Huang-HUST',
 'TS092': 'Seamount',
 'TS094': 'SimRNA-server',
 'TS097': 'JFK-THG-IDPCONFGEN',
 'TS100': 'zurite_lab',
 'TS102': 'Psi-Phi',
 'TS105': 'PFSC-PFVM',
 'TS110': 'MIEnsembles-Server',
 'TS112': 'Seder2024easy',
 'TS114': 'COAST',
 'TS117': 'Vakser',
 'TS120': 'Cerebra',
 'TS121': 'Pascal_Auffinger',
 'TS122': 'MQA_server',
 'TS128': 'TheMeilerMethod',
 'TS132': 'profold2',
 'TS135': 'Lindorff-LarsenCLVDS',
 'TS136': 'Lindorff-LarsenM3PPS',
 'TS137': 'Lindorff-LarsenM3PWS',
 'TS138': 'Shengyi',
 'TS139': 'DeepFold-refine',
 'TS143': 'dMNAfold',
 'TS145': 'colabfold_baseline',
 'TS147': 'Zheng-Multimer',
 'TS148': 'Guijunlab-Complex',
 'TS156': 'SoutheRNA',
 'TS159': '406',
 'TS163': 'MultiFOLD2',
 'TS164': 'McGuffin',
 'TS165': 'dfr',
 'TS167': 'OpenComplex',
 'TS169': 'thermomaps',
 'TS171': 'ChaePred',
 'TS172': 'VoroAffinity',
 'TS174': 'colabfold_foldseek',
 'TS177': 'aicb',
 'TS183': 'GuangzhouRNA-human',
 'TS187': 'Ayush',
 'TS188': 'VifChartreuseJaune',
 'TS189': 'LCBio',
 'TS191': 'Schneidman',
 'TS196': 'HYU_MLLAB',
 'TS197': 'D3D',
 'TS198': 'colabfold',
 'TS201': 'Drugit',
 'TS202': 'test001',
 'TS204': 'Zou',
 'TS207': 'MULTICOM_ligand',
 'TS208': 'falcon2',
 'TS209': 'colabfold_human',
 'TS212': 'PIEFold_human',
 'TS217': 'zyh_mae_try1E',
 'TS218': 'HIT-LinYang',
 'TS219': 'XGroup-server',
 'TS221': 'CSSB_FAKER',
 'TS225': 'N/A',
 'TS226': 'Pfaender',
 'TS227': 'KUMC',
 'TS231': 'B-LAB',
 'TS235': 'isyslab-hust',
 'TS237': 'Convex-PL-R',
 'TS238': 'BRIQX',
 'TS241': 'elofsson',
 'TS261': 'UNRES',
 'TS262': 'CoDock',
 'TS264': 'GuijunLab-Human',
 'TS267': 'kiharalab_server',
 'TS269': 'CSSB_server',
 'TS271': 'mialab_prediction2',
 'TS272': 'GromihaLab',
 'TS273': 'MQA_base',
 'TS274': 'kozakovvajda',
 'TS275': 'Seminoles',
 'TS276': 'FrederickFolding',
 'TS281': 'T2DUCC',
 'TS284': 'Unicorn',
 'TS286': 'CSSB_experimental',
 'TS287': 'plmfold',
 'TS290': 'Pierce',
 'TS293': 'MRAH',
 'TS294': 'KiharaLab',
 'TS295': 'VoroAffinityB',
 'TS298': 'ShanghaiTech-human',
 'TS300': 'ARC',
 'TS301': 'GHZ-MAN',
 'TS304': 'AF3-server',
 'TS306': 'GeneSilicoRNA-server',
 'TS307': 'nfRNA',
 'TS308': 'MoMAteam1',
 'TS309': 'Koes',
 'TS311': 'RAGfold_Prot1',
 'TS312': 'GuijunLab-Assembly',
 'TS314': 'GuijunLab-PAthreader',
 'TS317': 'GuangzhouRNA_AI',
 'TS319': 'MULTICOM_LLM',
 'TS322': 'XGroup',
 'TS323': 'Yan',
 'TS325': '405',
 'TS331': 'MULTICOM_AI',
 'TS337': 'APOLLO',
 'TS338': 'GeneSilico',
 'TS345': 'MULTICOM_human',
 'TS349': 'cheatham-lab',
 'TS351': 'digiwiser-ensemble',
 'TS353': 'KORP-PL-W',
 'TS355': 'CMOD',
 'TS357': 'UTAustin',
 'TS358': 'PerezLab_Gators',
 'TS361': 'Cerebra_server',
 'TS363': '2Vinardo',
 'TS367': 'AIR',
 'TS369': 'Bhattacharya',
 'TS370': 'DrAshokAndFriends',
 'TS375': 'milliseconds',
 'TS376': 'OFsingleseq',
 'TS380': 'mialab_prediction',
 'TS384': 'pert-plddt',
 'TS386': 'ShanghaiTech-Ligand',
 'TS388': 'DeepFold-server',
 'TS391': 'bussilab_replex',
 'TS393': 'GuijunLab-QA',
 'TS397': 'smg_ulaval',
 'TS400': 'OmniFold',
 'TS403': 'mmagnus',
 'TS408': 'SNU-CHEM-lig',
 'TS412': 'cheatham-lab_villa',
 'TS416': 'GPLAffinity',
 'TS417': 'GuangzhouRNA-meta',
 'TS418': 'Lee-Shin',
 'TS419': 'CSSB-Human',
 'TS420': 'Zou_aff2',
 'TS423': 'ShanghaiTech-server',
 'TS425': 'MULTICOM_GATE',
 'TS432': 'DIMAIO',
 'TS435': 'RNAFOLDX',
 'TS436': 'Yoshiaki',
 'TS439': 'Dokholyan',
 'TS441': 'ModFOLDdock2',
 'TS443': 'MQA',
 'TS446': 'pDockQ2',
 'TS447': 'UDMod',
 'TS448': 'dNAfold',
 'TS450': 'OpenComplex_Server',
 'TS456': 'Yang-Multimer',
 'TS461': 'forlilab',
 'TS462': 'Zheng',
 'TS464': 'PocketTracer',
 'TS465': 'Wallner',
 'TS466': 'coogs3',
 'TS468': 'MIALAB_gong',
 'TS469': 'GruLab',
 'TS471': 'Pcons',
 'TS474': 'CCB-AlGDock',
 'TS475': 'ptq',
 'TS476': 'VifChartreuse',
 'TS481': 'Vfold',
 'TS485': 'bussilab_plain_md',
 'TS489': 'Fernandez-Recio',
 'TS494': 'ClusPro',
 'TS496': 'AF_unmasked'}
group2number={'JFK-THG-AMBER': 'TS002',
 'JFK-THG-AMBERstable': 'TS003',
 'JFK-THG-CHARMM': 'TS004',
 'JFK-THG-CHARMMstable': 'TS005',
 'RNA_Dojo': 'TS006',
 'HADDOCK': 'TS008',
 'Cool-PSP': 'TS014',
 'PEZYFoldings': 'TS015',
 'haiping': 'TS016',
 'Seder2024hard': 'TS017',
 'AttStructureScorer': 'TS018',
 'Zheng-Server': 'TS019',
 'comppharmunibas': 'TS020',
 'Yang': 'TS022',
 'FTBiot0119': 'TS023',
 'SwRI': 'TS026',
 'ModFOLDdock2R': 'TS027',
 'NKRNA-s': 'TS028',
 'zyh_mae_try1': 'TS029',
 'SNU-CHEM_aff': 'TS030',
 'MassiveFold': 'TS031',
 'Bryant': 'TS032',
 'Diff': 'TS033',
 'arosko': 'TS039',
 'DELCLAB': 'TS040',
 'N/A': 'TS225',
 'UTMB': 'TS049',
 'SHORTLE': 'TS050',
 'MULTICOM': 'TS051',
 'Yang-Server': 'TS052',
 'LCDD-team': 'TS055',
 'DeepFold': 'TS059',
 'RNApolis': 'TS063',
 'ModFOLDdock2S': 'TS074',
 'GHZ-ISM': 'TS075',
 'coogs2': 'TS077',
 'MRAFold': 'TS079',
 'pDockQ': 'TS080',
 'VnsDock': 'TS082',
 'Vendruscolo': 'TS084',
 'Bates': 'TS085',
 'orangeballs': 'TS088',
 'Huang-HUST': 'TS091',
 'Seamount': 'TS092',
 'SimRNA-server': 'TS094',
 'JFK-THG-IDPCONFGEN': 'TS097',
 'zurite_lab': 'TS100',
 'Psi-Phi': 'TS102',
 'PFSC-PFVM': 'TS105',
 'MIEnsembles-Server': 'TS110',
 'Seder2024easy': 'TS112',
 'COAST': 'TS114',
 'Vakser': 'TS117',
 'Cerebra': 'TS120',
 'Pascal_Auffinger': 'TS121',
 'MQA_server': 'TS122',
 'TheMeilerMethod': 'TS128',
 'profold2': 'TS132',
 'Lindorff-LarsenCLVDS': 'TS135',
 'Lindorff-LarsenM3PPS': 'TS136',
 'Lindorff-LarsenM3PWS': 'TS137',
 'Shengyi': 'TS138',
 'DeepFold-refine': 'TS139',
 'dMNAfold': 'TS143',
 'colabfold_baseline': 'TS145',
 'Zheng-Multimer': 'TS147',
 'Guijunlab-Complex': 'TS148',
 'SoutheRNA': 'TS156',
 '406': 'TS159',
 'MultiFOLD2': 'TS163',
 'McGuffin': 'TS164',
 'dfr': 'TS165',
 'OpenComplex': 'TS167',
 'thermomaps': 'TS169',
 'ChaePred': 'TS171',
 'VoroAffinity': 'TS172',
 'colabfold_foldseek': 'TS174',
 'aicb': 'TS177',
 'GuangzhouRNA-human': 'TS183',
 'Ayush': 'TS187',
 'VifChartreuseJaune': 'TS188',
 'LCBio': 'TS189',
 'Schneidman': 'TS191',
 'HYU_MLLAB': 'TS196',
 'D3D': 'TS197',
 'colabfold': 'TS198',
 'Drugit': 'TS201',
 'test001': 'TS202',
 'Zou': 'TS204',
 'MULTICOM_ligand': 'TS207',
 'falcon2': 'TS208',
 'colabfold_human': 'TS209',
 'PIEFold_human': 'TS212',
 'zyh_mae_try1E': 'TS217',
 'HIT-LinYang': 'TS218',
 'XGroup-server': 'TS219',
 'CSSB_FAKER': 'TS221',
 'Pfaender': 'TS226',
 'KUMC': 'TS227',
 'B-LAB': 'TS231',
 'isyslab-hust': 'TS235',
 'Convex-PL-R': 'TS237',
 'BRIQX': 'TS238',
 'elofsson': 'TS241',
 'UNRES': 'TS261',
 'CoDock': 'TS262',
 'GuijunLab-Human': 'TS264',
 'kiharalab_server': 'TS267',
 'CSSB_server': 'TS269',
 'mialab_prediction2': 'TS271',
 'GromihaLab': 'TS272',
 'MQA_base': 'TS273',
 'kozakovvajda': 'TS274',
 'Seminoles': 'TS275',
 'FrederickFolding': 'TS276',
 'T2DUCC': 'TS281',
 'Unicorn': 'TS284',
 'CSSB_experimental': 'TS286',
 'plmfold': 'TS287',
 'Pierce': 'TS290',
 'MRAH': 'TS293',
 'KiharaLab': 'TS294',
 'VoroAffinityB': 'TS295',
 'ShanghaiTech-human': 'TS298',
 'ARC': 'TS300',
 'GHZ-MAN': 'TS301',
 'AF3-server': 'TS304',
 'GeneSilicoRNA-server': 'TS306',
 'nfRNA': 'TS307',
 'MoMAteam1': 'TS308',
 'Koes': 'TS309',
 'RAGfold_Prot1': 'TS311',
 'GuijunLab-Assembly': 'TS312',
 'GuijunLab-PAthreader': 'TS314',
 'GuangzhouRNA_AI': 'TS317',
 'MULTICOM_LLM': 'TS319',
 'XGroup': 'TS322',
 'Yan': 'TS323',
 '405': 'TS325',
 'MULTICOM_AI': 'TS331',
 'APOLLO': 'TS337',
 'GeneSilico': 'TS338',
 'MULTICOM_human': 'TS345',
 'cheatham-lab': 'TS349',
 'digiwiser-ensemble': 'TS351',
 'KORP-PL-W': 'TS353',
 'CMOD': 'TS355',
 'UTAustin': 'TS357',
 'PerezLab_Gators': 'TS358',
 'Cerebra_server': 'TS361',
 '2Vinardo': 'TS363',
 'AIR': 'TS367',
 'Bhattacharya': 'TS369',
 'DrAshokAndFriends': 'TS370',
 'milliseconds': 'TS375',
 'OFsingleseq': 'TS376',
 'mialab_prediction': 'TS380',
 'pert-plddt': 'TS384',
 'ShanghaiTech-Ligand': 'TS386',
 'DeepFold-server': 'TS388',
 'bussilab_replex': 'TS391',
 'GuijunLab-QA': 'TS393',
 'smg_ulaval': 'TS397',
 'OmniFold': 'TS400',
 'mmagnus': 'TS403',
 'SNU-CHEM-lig': 'TS408',
 'cheatham-lab_villa': 'TS412',
 'GPLAffinity': 'TS416',
 'GuangzhouRNA-meta': 'TS417',
 'Lee-Shin': 'TS418',
 'CSSB-Human': 'TS419',
 'Zou_aff2': 'TS420',
 'ShanghaiTech-server': 'TS423',
 'MULTICOM_GATE': 'TS425',
 'DIMAIO': 'TS432',
 'RNAFOLDX': 'TS435',
 'Yoshiaki': 'TS436',
 'Dokholyan': 'TS439',
 'ModFOLDdock2': 'TS441',
 'MQA': 'TS443',
 'pDockQ2': 'TS446',
 'UDMod': 'TS447',
 'dNAfold': 'TS448',
 'OpenComplex_Server': 'TS450',
 'Yang-Multimer': 'TS456',
 'forlilab': 'TS461',
 'Zheng': 'TS462',
 'PocketTracer': 'TS464',
 'Wallner': 'TS465',
 'coogs3': 'TS466',
 'MIALAB_gong': 'TS468',
 'GruLab': 'TS469',
 'Pcons': 'TS471',
 'CCB-AlGDock': 'TS474',
 'ptq': 'TS475',
 'VifChartreuse': 'TS476',
 'Vfold': 'TS481',
 'bussilab_plain_md': 'TS485',
 'Fernandez-Recio': 'TS489',
 'ClusPro': 'TS494',
 'AF_unmasked': 'TS496'}
AF2_dict={'TS002': 'N/A',
 'TS003': 'N/A',
 'TS004': 'N/A',
 'TS005': 'N/A',
 'TS006': 'N',
 'TS008': 'N/A',
 'TS014': 'Y',
 'TS015': 'Y',
 'TS016': 'N/A',
 'TS017': 'N',
 'TS018': 'N/A',
 'TS019': 'Y',
 'TS020': 'N/A',
 'TS022': 'Y',
 'TS023': 'N',
 'TS026': 'N/A',
 'TS027': 'Y',
 'TS028': 'Y',
 'TS029': 'N/A',
 'TS030': 'Y',
 'TS031': 'Y',
 'TS032': 'N/A',
 'TS033': 'N/A',
 'TS039': 'N',
 'TS040': 'Y',
 'TS044': 'N/A',
 'TS049': 'N/A',
 'TS050': 'N',
 'TS051': 'Y',
 'TS052': 'Y',
 'TS055': 'N',
 'TS059': 'Y',
 'TS063': 'N',
 'TS074': 'Y',
 'TS075': 'Y',
 'TS077': 'N',
 'TS079': 'Y',
 'TS080': 'N',
 'TS082': 'N/A',
 'TS084': 'N/A',
 'TS085': 'N/A',
 'TS088': 'Y',
 'TS091': 'Y',
 'TS092': 'N/A',
 'TS094': 'N',
 'TS097': 'N/A',
 'TS100': 'N/A',
 'TS102': 'N/A',
 'TS105': 'N',
 'TS110': 'Y',
 'TS112': 'N',
 'TS114': 'Y',
 'TS117': 'Y',
 'TS120': 'N/A',
 'TS121': 'N',
 'TS122': 'Y',
 'TS128': 'N/A',
 'TS132': 'N/A',
 'TS135': 'Y',
 'TS136': 'N/A',
 'TS137': 'N/A',
 'TS138': 'N/A',
 'TS139': 'Y',
 'TS143': 'N/A',
 'TS435': 'Use MSA',
 'TS436': 'N/A',
 'TS439': 'N/A',
 'TS441': 'Use MSA',
 'TS443': 'No MSA',
 'TS446': 'Use MSA',
 'TS447': 'N/A',
 'TS448': 'No MSA',
 'TS450': 'Use MSA',
 'TS456': 'Enhanced MSA',
 'TS461': 'N/A',
 'TS462': 'Enhanced MSA',
 'TS464': 'Use MSA',
 'TS465': 'Enhanced MSA',
 'TS466': 'No MSA',
 'TS468': 'N/A',
 'TS469': 'No MSA',
 'TS471': 'Use MSA',
 'TS474': 'N/A',
 'TS475': 'N/A',
 'TS476': 'No MSA',
 'TS481': 'Use MSA',
 'TS485': 'No MSA',
 'TS489': 'Use MSA',
 'TS494': 'Use MSA',
 'TS496': 'No MSA'}

# %%
parameters = [
    # ["first", "nn"],
    #           ["first", "np"],
    #           ["first", "pp"],
              ["best", "nn", 15],
              ["best", "np", 15],
              ["best", "pp", 15],
              ["best", "all", 15],
              ]
result_path = "/data/data1/conglab/qcong/CASP16/stage2_hybrid_ranks/"

for parameter in parameters:
    model, interface, top_n = parameter
    file_name = None
    if model == "best":
        if interface == "nn":
            file_name = "step7_best_NN"
        if interface == "np":
            file_name = "step7_best_NP"
        if interface == "pp":
            file_name = "step7_best_PP"
        if interface == "all":
            file_name = "step7_best_ALL"
    if model == "first":
        if interface == "nn":
            file_name = "step7_first_NN"
        if interface == "np":
            file_name = "step7_first_NP"
        if interface == "pp":
            file_name = "step7_first_PP"
        if interface == "all":
            file_name = "step7_first_ALL"
    print(file_name)
    fig_dir = "./CASP16_figures_final/"
    if not os.path.exists(fig_dir):
        os.makedirs(fig_dir)
    if interface == "all":
        df = pd.read_csv(result_path + file_name, sep="\t", header=None, names=["groups","targets_number", "sum", "IPS", "ICS", "QSbest", "TM-score"])
    else:
        df = pd.read_csv(result_path + file_name, sep="\t", header=None, names=["groups","targets_number", "sum", "IPS", "ICS", "QSbest"])

    df.set_index("groups", inplace=True)
    print(df)
    largest_sum = df["sum"].max()
    if interface == "all":
        measures = ["IPS", "ICS", "QSbest", "TM-score"]
    else:
        measures = ["IPS", "ICS", "QSbest"]
    score_df = df[measures]
    score_df = score_df.head(top_n)
    groups = score_df.index.to_list()
    if interface == "all":
        IPS = score_df["IPS"].to_list()
        ICS = score_df["ICS"].to_list()
        QSbest = score_df["QSbest"].to_list()
        TM_score = score_df["TM-score"].to_list()
    else:
        IPS = score_df["IPS"].to_list()
        ICS = score_df["ICS"].to_list()
        QSbest = score_df["QSbest"].to_list()
    groups = [number2group[group] for group in groups]
    if interface == "all":
        all_scores = [IPS, ICS, QSbest, TM_score]
    else:
        all_scores = [IPS, ICS, QSbest]
    positive_series = [[val if val > 0 else 0 for val in series] for series in all_scores]
    negative_series = [[val if val < 0 else 0 for val in series] for series in all_scores]
    print(positive_series)
    print(negative_series)
    print(len(positive_series))
    print(len(negative_series))
    max_positive_list = [0 for i in range(len(groups))]
    max_negative_list = [0 for i in range(len(groups))]
    for i in range(len(positive_series)):
        score = positive_series[i]
        for j in range(len(score)):
            max_positive_list[j] += score[j]
    for i in range(len(negative_series)):
        score = negative_series[i]
        for j in range(len(score)):
            max_negative_list[j] += score[j]
    max_positive = max(max_positive_list)
    max_negative = min(max_negative_list)
    print(max_positive_list)
    print(max_negative_list)


    if top_n > 10:
        fig = plt.figure(figsize=(4, 6), dpi=300)
        bottom_positive = np.zeros(len(groups))
        bottom_negative = np.zeros(len(groups))
        colors = ['tab:blue', 'tab:green', 'tab:orange', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive']

        for i, series in enumerate(positive_series):
            plt.bar(groups, series, bottom=bottom_positive, color=colors[i], alpha=0.9)
            bottom_positive += series

        for i, series in enumerate(negative_series):
            plt.bar(groups, series, bottom=bottom_negative, color=colors[i], alpha=0.5)
            bottom_negative += series

        # plt.title(f'models: {model}, difficulty: {mode}, phase: {phase}, impute:{impute_value}, top_n: {top_n}, ', fontsize=12, pad=20)
        plt.title(f'models: {model}, top_n: {top_n}, interface: {interface}', fontsize=12, pad=20)
        plt.legend(measures, loc='upper right',fontsize=8)

        for group, value in zip(groups, max_positive_list):
            group_id = group2number[group]
            if AF2_dict[group_id] == "Y":
                # draw a dot on the top, and move up a little bit
                plt.plot(group, value+16, color='red', marker='o', markersize=5)
            elif AF2_dict[group_id] == "N":
                plt.plot(group, value+16, color='red', marker='x', markersize=5)
            
            if AF3_dict[group_id] == "Y":
                # draw a dot on the top, and move up a little bit
                plt.plot(group, value+12, color='blue', marker='o', markersize=5)
            elif AF3_dict[group_id] == "N":
                plt.plot(group, value+12, color='blue', marker='x', markersize=5)

            if PLM_dict[group_id] == "Y":
                # draw a dot on the top, and move up a little bit
                plt.plot(group, value+8, color='green', marker='o', markersize=5)
            elif PLM_dict[group_id] == "N":
                plt.plot(group, value+8, color='green', marker='x', markersize=5)

            if MSA_dict[group_id] == "Enhanced MSA":
                # draw a dot on the top, and move up a little bit
                plt.plot(group, value+4, color='orange', marker='o', markersize=5)
            elif MSA_dict[group_id] == "Use MSA":
                plt.plot(group, value+4, color='orange', marker='x', markersize=5)
            elif MSA_dict[group_id] == "No MSA":
                plt.plot(group, value+10, color='orange', marker='^', markersize=5)

        plt.xticks(rotation=90, fontsize=15)
        # y range : -5 to 95
        # if model == "best":
        #     plt.ylim(-5, 105)
        # elif model == "first":
        #     plt.ylim(-10, 75)
        plt.ylim(max_negative-5,max_positive+55)
        plt.ylabel('cumulative z-score', fontsize=15)
        plt.yticks(fontsize=15)
        plt.tight_layout()
        plt.show()
        # fig.savefig(fig_dir+f"sum_z_score_{model}_{mode}_{phase}_impute={impute_value}_top_n={top_n}.png")

    else:
        fig = plt.figure(figsize=(3, 4), dpi=300)
        bottom_positive = np.zeros(len(groups))
        bottom_negative = np.zeros(len(groups))

        colors = ['tab:blue', 'tab:green', 'tab:orange', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive']

        for i, series in enumerate(positive_series):
            plt.bar(groups, series, bottom=bottom_positive, color=colors[i], alpha=0.9)
            bottom_positive += series

        for i, series in enumerate(negative_series):
            plt.bar(groups, series, bottom=bottom_negative, color=colors[i], alpha=0.5)
            bottom_negative += series
        # plt.title(f'models: {model}, difficulty: {mode}, phase: {phase}, impute:{impute_value}, top_n: {top_n}, ', fontsize=6, pad=20)
        plt.title(f'models: {model}, top_n: {top_n}, interface: {interface}', fontsize=6, pad=20)
        plt.legend(measures, loc='upper right',fontsize=6)


        for group, value in zip(groups, df["sum"]):
            group_id = group2number[group]
            if AF2_dict[group_id] == "Y":
                # draw a dot on the top, and move up a little bit
                plt.plot(group, value+20, color='red', marker='o', markersize=5)
            elif AF2_dict[group_id] == "N":
                plt.plot(group, value+20, color='red', marker='x', markersize=5)
            
            if AF3_dict[group_id] == "Y":
                # draw a dot on the top, and move up a little bit
                plt.plot(group, value+15, color='blue', marker='o', markersize=5)
            elif AF3_dict[group_id] == "N":
                plt.plot(group, value+15, color='blue', marker='x', markersize=5)

            if PLM_dict[group_id] == "Y":
                # draw a dot on the top, and move up a little bit
                plt.plot(group, value+10, color='green', marker='o', markersize=5)
            elif PLM_dict[group_id] == "N":
                plt.plot(group, value+10, color='green', marker='x', markersize=5)

            if MSA_dict[group_id] == "Enhanced MSA":
                # draw a dot on the top, and move up a little bit
                plt.plot(group, value+5, color='orange', marker='o', markersize=5)
            elif MSA_dict[group_id] == "Use MSA":
                plt.plot(group, value+5, color='orange', marker='x', markersize=5)
            elif MSA_dict[group_id] == "No MSA":
                plt.plot(group, value+5, color='orange', marker='^', markersize=5)

        plt.xticks(rotation=90, fontsize=10)
        # y range : -5 to 95
        # if model == "best":
        #     plt.ylim(-5, 105)
        # elif model == "first":
        #     plt.ylim(-10, 75)
        plt.ylim(max_negative-5,largest_sum+55)
        plt.ylabel('cumulative z-score', fontsize=10)
        plt.yticks(fontsize=10)
        plt.tight_layout()
        plt.show()
# Out:
# step7_best_NN
#         targets_number      sum      IPS      ICS   QSbest
# groups
# TS262               12  17.4204   4.8107   5.4679   7.1418
# TS481               12  16.0520   4.4642   5.1352   6.4526
# TS294               12  15.1954   5.4244   2.5837   7.1872
# TS028               12  10.8115   3.7683   3.5063   3.5369
# TS304               12  10.7864   3.3369   3.2369   4.2126
# TS241               12   9.3761   1.7548   2.9163   4.7049
# TS110               12   8.3440   2.3421   2.4744   3.5274
# TS033               11   5.3220   1.4678   1.9800   1.8742
# TS286               12   4.6686   3.6343   1.4463  -0.4120
# TS231               11   3.7162   1.1589   1.0476   1.5097
# TS462               11   3.3961   1.0830   1.1075   1.2056
# TS338                8   3.0419  -0.5753   0.9674   2.6498
# TS167               11  -1.1893  -0.6781  -2.1028   1.5915
# TS450               10  -2.0815   0.1709  -2.4739   0.2215
# ...

# %%
parameters = [
    # ["first", "nn"],
    #           ["first", "np"],
    #           ["first", "pp"],
              ["best", "nn", 15],
              ["best", "np", 15],
              ["best", "pp", 15],
              ["best", "all", 15],
              ]
for parameter in parameters:
    model = parameter[0]
    interface = parameter[1]
    top_n = parameter[2]
    matrix_name = None
    if model == "best":
        if interface == "nn":
            matrix_name = "step8_best_NN.mtx"
        if interface == "np":
            matrix_name = "step8_best_NP.mtx"
        if interface == "pp":
            matrix_name = "step8_best_PP.mtx"
        if interface == "all":
            matrix_name = "step8_best_ALL.mtx"
    if model == "first":
        if interface == "nn":
            matrix_name = "step8_best_NN.mtx"
        if interface == "np":
            matrix_name = "step8_best_NP.mtx"
        if interface == "pp":
            matrix_name = "step8_best_PP.mtx"
        if interface == "all":
            matrix_name = "step8_best_ALL.mtx"
    print(matrix_name)
    # top_n = 22
    mtx = pd.read_csv(result_path + matrix_name, sep="\t", index_col=0)
    # impute diag na with 0
    mtx = mtx.apply(pd.to_numeric, errors='coerce')
    mtx = mtx.fillna(0)
    # multiply by 100
    mtx = mtx * 100
    bootstrap_rank = mtx.index.to_list()
    bootstrap_rank = [number2group[group] for group in bootstrap_rank]
    # print(mtx.shape)

    # to np.array
    bootstrap_array = mtx.to_numpy()
    # print(bootstrap_array)

    if top_n < 22:
        # Subset the matrix to only include top_n groups
        bootstrap_array = bootstrap_array[:top_n, :top_n]
        bootstrap_rank = bootstrap_rank[:top_n]
    
    if top_n >= 16:
        plt.figure(figsize=(12, 9), dpi=300)
    elif top_n < 16:
        plt.figure(figsize=(10, 7.5), dpi=300)

        
    ax = sns.heatmap(bootstrap_array, annot=True, 
                    #  fmt should save 0 digit
                    fmt='.0f',
                    cmap='Greys', cbar=True, square=True,
                    xticklabels= bootstrap_rank, yticklabels=bootstrap_rank,
                    #   linewidths=1, linecolor='black',
                    )

    for text in ax.texts:
        value = float(text.get_text())
        if value >= 95:
            text.set_color('red')
        elif value < 95 and value >= 75:
            text.set_color('white')
        else:
            text.set_color('black')

    cbar = ax.collections[0].colorbar
    cbar.set_ticks([0, 25, 50, 75, 100])
    cbar.set_ticklabels([0, 25, 50, 75, 100])
    cbar.ax.tick_params(labelsize=12)

    for _, spine in ax.spines.items():
        spine.set_visible(True)
        spine.set_linewidth(2)
    # ax.set_xticklabels(ax.get_xticklabels())
    # ax.set_yticklabels(ax.get_yticklabels())
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, fontsize=15)
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=15)
    # plt.xticks(np.arange(top_n), bootstrap_rank,rotation=90, fontsize=18)
    # plt.yticks(np.arange(top_n), bootstrap_rank, rotation=0, fontsize=18)
    plt.title(f"models: {model}, top_n: {top_n}, interface: {interface}", fontsize=20, pad=30)
    # if equal_weight:
    #     plt.title("bootstrap result of {} score for {} models, {} targets, top {} groups, equal weight".format(
    #         measure_type, model, mode, top_n), fontsize=16, pad=20)
    # else:
    #     plt.title("bootstrap result of {} score for {} models, {} targets, top {} groups".format(
    #         measure_type, model, mode, top_n), fontsize=16, pad=20)
    fig_path = "./CASP16_figures_final/"
    plt.tight_layout()
    # png_top_file = f"bootstrap_{model}_{mode}_{phase}_impute={impute_value}_top_{top_n}.png"
    # plt.savefig(fig_path + png_top_file, dpi=300)
    plt.show()
# Out:
# step8_best_NN.mtx
# step8_best_NP.mtx
# step8_best_PP.mtx
# step8_best_ALL.mtx
